# %%
import pandas as pd

# %%
df= pd.read_excel("../data/GENERAL_WELL_DATA/Checkshot.xlsx")

# %%
df.shape
# Out:
# (19, 10)

# %%
df
# Out:
#     unique_wellbore_identifier wellbore_name  table_name time_type  \
# 0                          NaN        WELL-6         NaN   two-way
# 1                          NaN        WELL-6         NaN   two-way
# 2                          NaN        WELL-6         NaN   two-way
# 3                          NaN        WELL-6         NaN   two-way
# 4                          NaN        WELL-6         NaN   two-way
# 5                          NaN        WELL-6         NaN   two-way
# 6                          NaN        WELL-6         NaN   two-way
# 7                          NaN        WELL-6         NaN   two-way
# 8                          NaN        WELL-6         NaN   two-way
# 9                          NaN        WELL-6         NaN   two-way
# 10                         NaN        WELL-6         NaN   two-way
# 11                         NaN        WELL-6         NaN   two-way
# 12                         NaN        WELL-6         NaN   two-way
# ...
